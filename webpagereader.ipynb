# %%
import os
from dotenv import load_dotenv

from llama_index.core import Settings, VectorStoreIndex
from llama_index.readers.web import SimpleWebPageReader

from llama_index.llms.google_genai import GoogleGenAI
from llama_index.embeddings.google_genai import GoogleGenAIEmbedding

# %%
# Load environment variables
load_dotenv()
# Out:
# True

# %%
# Get Gemini API key
GOOGLE_API_KEY = os.getenv("GOOGLE_API_KEY")

# %%
# Configure Gemini LLM
Settings.llm = GoogleGenAI(
    model="gemini-2.5-flash",
    api_key=GOOGLE_API_KEY,
)

# %%
# Configure Gemini Embedding Model
Settings.embed_model = GoogleGenAIEmbedding(
    model_name="gemini-embedding-2-preview",
    api_key=GOOGLE_API_KEY,
)

# %%
def main(url: str):
    # Load webpage
    documents = SimpleWebPageReader(
        html_to_text=True
    ).load_data(urls=[url])

    # Create index
    index = VectorStoreIndex.from_documents(documents)

    # Create query engine
    query_engine = index.as_query_engine(similarity_top_k=2)

    # Ask a question
    response = query_engine.query(
        "What is Artificial Intelligence?"
    )

    print("\nAnswer:\n")
    print(response)

# %%
import nest_asyncio
nest_asyncio.apply()

# %%
if __name__ == "__main__":
    main(
        "https://cloud.google.com/learn/what-is-artificial-intelligence"
    )
# Out:
# Answer:
#
# Artificial intelligence (AI) is a field of computer science dedicated to developing smart machines capable of performing tasks that typically necessitate human intelligence, such as learning, reasoning, and problem-solving. It represents a collection of technologies that enable computers to learn, reason, and execute advanced tasks in ways that previously required human intellect, including understanding language, analyzing data, and offering helpful suggestions.
#
# This transformative technology draws from various disciplines, including computer science, data analytics, statistics, hardware and software engineering, linguistics, neuroscience, philosophy, and psychology. Essentially, AI aims to teach computers to emulate the complex abilities of the human brain, from comprehending the surrounding world to acquiring new knowledge and generating novel ideas.
