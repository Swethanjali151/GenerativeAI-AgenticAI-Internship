# %%
pip install -U langchain[openai]
# Out:
# Collecting langchain[openai]
#   Using cached langchain-1.3.4-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: langchain-core<2.0.0,>=1.4.0 in c:\users\sweth\anaconda3_new\lib\site-packages (from langchain[openai]) (1.4.0)
# Collecting langgraph<1.3.0,>=1.2.4 (from langchain[openai])
#   Using cached langgraph-1.2.4-py3-none-any.whl.metadata (8.0 kB)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\sweth\anaconda3_new\lib\site-packages (from langchain[openai]) (2.12.4)
# Collecting langchain-openai (from langchain[openai])
#   Downloading langchain_openai-1.2.2-py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\sweth\anaconda3_new\lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain[openai]) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.14 in c:\users\sweth\anaconda3_new\lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain[openai]) (0.0.16)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\sweth\anaconda3_new\lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain[openai]) (0.8.9)
# Requirement already satisfied: packaging>=23.2.0 in c:\users\sweth\anaconda3_new\lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain[openai]) (25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\sweth\anaconda3_new\lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain[openai]) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\sweth\anaconda3_new\lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain[openai]) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\sweth\anaconda3_new\lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain[openai]) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\sweth\anaconda3_new\lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain[openai]) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\sweth\anaconda3_new\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.4.0->langchain[openai]) (3.0.0)
# Collecting langgraph-checkpoint<5.0.0,>=4.1.0 (from langgraph<1.3.0,>=1.2.4->langchain[openai])
#   Using cached langgraph_checkpoint-4.1.1-py3-none-any.whl.metadata (5.2 kB)
# Collecting langgraph-prebuilt<1.2.0,>=1.1.0 (from langgraph<1.3.0,>=1.2.4->langchain[openai])
#   Using cached langgraph_prebuilt-1.1.0-py3-none-any.whl.metadata (5.2 kB)
# Collecting langgraph-sdk<0.5.0,>=0.4.2 (from langgraph<1.3.0,>=1.2.4->langchain[openai])
#   Using cached langgraph_sdk-0.4.2-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: xxhash>=3.5.0 in c:\users\sweth\anaconda3_new\lib\site-packages (from langgraph<1.3.0,>=1.2.4->langchain[openai]) (3.7.0)
# Collecting ormsgpack>=1.12.0 (from langgraph-checkpoint<5.0.0,>=4.1.0->langgraph<1.3.0,>=1.2.4->langchain[openai])
#   Using cached ormsgpack-1.12.2-cp313-cp313-win_amd64.whl.metadata (3.3 kB)
# Requirement already satisfied: httpx>=0.25.2 in c:\users\sweth\anaconda3_new\lib\site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.4->langchain[openai]) (0.28.1)
# Requirement already satisfied: orjson>=3.11.5 in c:\users\sweth\anaconda3_new\lib\site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.4->langchain[openai]) (3.11.9)
# Collecting websockets<16,>=14 (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.4->langchain[openai])
#   Using cached websockets-15.0.1-cp313-cp313-win_amd64.whl.metadata (7.0 kB)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\sweth\anaconda3_new\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain[openai]) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\sweth\anaconda3_new\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain[openai]) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\sweth\anaconda3_new\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain[openai]) (0.24.0)
# Requirement already satisfied: anyio in c:\users\sweth\anaconda3_new\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.4->langchain[openai]) (4.10.0)
# Requirement already satisfied: certifi in c:\users\sweth\anaconda3_new\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.4->langchain[openai]) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in c:\users\sweth\anaconda3_new\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.4->langchain[openai]) (1.0.9)
# Requirement already satisfied: idna in c:\users\sweth\anaconda3_new\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.4->langchain[openai]) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\sweth\anaconda3_new\lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.4->langchain[openai]) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\sweth\anaconda3_new\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain[openai]) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\sweth\anaconda3_new\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain[openai]) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\sweth\anaconda3_new\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain[openai]) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\sweth\anaconda3_new\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain[openai]) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sweth\anaconda3_new\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain[openai]) (2.5.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\sweth\anaconda3_new\lib\site-packages (from anyio->httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.4->langchain[openai]) (1.3.0)
# Collecting openai<3.0.0,>=2.26.0 (from langchain-openai->langchain[openai])
#   Downloading openai-2.41.0-py3-none-any.whl.metadata (32 kB)
# Collecting tiktoken<1.0.0,>=0.7.0 (from langchain-openai->langchain[openai])
#   Downloading tiktoken-0.13.0-cp313-cp313-win_amd64.whl.metadata (6.8 kB)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\sweth\anaconda3_new\lib\site-packages (from openai<3.0.0,>=2.26.0->langchain-openai->langchain[openai]) (1.9.0)
# Collecting jiter<1,>=0.10.0 (from openai<3.0.0,>=2.26.0->langchain-openai->langchain[openai])
#   Downloading jiter-0.15.0-cp313-cp313-win_amd64.whl.metadata (5.3 kB)
# Requirement already satisfied: tqdm>4 in c:\users\sweth\anaconda3_new\lib\site-packages (from openai<3.0.0,>=2.26.0->langchain-openai->langchain[openai]) (4.67.1)
# Requirement already satisfied: regex in c:\users\sweth\anaconda3_new\lib\site-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai->langchain[openai]) (2025.9.1)
# Requirement already satisfied: colorama in c:\users\sweth\anaconda3_new\lib\site-packages (from tqdm>4->openai<3.0.0,>=2.26.0->langchain-openai->langchain[openai]) (0.4.6)
# Using cached langchain-1.3.4-py3-none-any.whl (125 kB)
# Using cached langgraph-1.2.4-py3-none-any.whl (245 kB)
# Using cached langgraph_checkpoint-4.1.1-py3-none-any.whl (56 kB)
# Using cached langgraph_prebuilt-1.1.0-py3-none-any.whl (41 kB)
# Using cached langgraph_sdk-0.4.2-py3-none-any.whl (160 kB)
# Using cached websockets-15.0.1-cp313-cp313-win_amd64.whl (176 kB)
# Using cached ormsgpack-1.12.2-cp313-cp313-win_amd64.whl (117 kB)
# Downloading langchain_openai-1.2.2-py3-none-any.whl (99 kB)
# Downloading openai-2.41.0-py3-none-any.whl (1.4 MB)
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ----------------------- ---------------- 0.8/1.4 MB 4.1 MB/s eta 0:00:01
#    ---------------------------------------- 1.4/1.4 MB 3.9 MB/s  0:00:00
# Downloading jiter-0.15.0-cp313-cp313-win_amd64.whl (196 kB)
# Downloading tiktoken-0.13.0-cp313-cp313-win_amd64.whl (874 kB)
#    ---------------------------------------- 0.0/874.8 kB ? eta -:--:--
#    ----------------------- ---------------- 524.3/874.8 kB 3.3 MB/s eta 0:00:01
#    ---------------------------------------- 874.8/874.8 kB 3.5 MB/s  0:00:00
# Installing collected packages: websockets, ormsgpack, jiter, tiktoken, openai, langgraph-sdk, langgraph-checkpoint, langchain-openai, langgraph-prebuilt, langgraph, langchain
#
#   Attempting uninstall: websockets
#
#     Found existing installation: websockets 16.0
#
#     Uninstalling websockets-16.0:
#
#       Successfully uninstalled websockets-16.0
#
#    ----------------------------------------  0/11 [websockets]
#    ----------------------------------------  0/11 [websockets]
#    ----------------------------------------  0/11 [websockets]
#    ----------------------------------------  0/11 [websockets]
#    ----------------------------------------  0/11 [websockets]
#    ----------------------------------------  0/11 [websockets]
#    ----------------------------------------  0/11 [websockets]
#    ----------------------------------------  0/11 [websockets]
#    ---------- -----------------------------  3/11 [tiktoken]
#    ---------- -----------------------------  3/11 [tiktoken]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    -------------- -------------------------  4/11 [openai]
#    ------------------ ---------------------  5/11 [langgraph-sdk]
#    ------------------ ---------------------  5/11 [langgraph-sdk]
#    ------------------ ---------------------  5/11 [langgraph-sdk]
#    ------------------ ---------------------  5/11 [langgraph-sdk]
#    ------------------ ---------------------  5/11 [langgraph-sdk]
#    ------------------ ---------------------  5/11 [langgraph-sdk]
#    ------------------ ---------------------  5/11 [langgraph-sdk]
#    ------------------ ---------------------  5/11 [langgraph-sdk]
#    ------------------ ---------------------  5/11 [langgraph-sdk]
#    --------------------- ------------------  6/11 [langgraph-checkpoint]
#    --------------------- ------------------  6/11 [langgraph-checkpoint]
#    --------------------- ------------------  6/11 [langgraph-checkpoint]
#    ------------------------- --------------  7/11 [langchain-openai]
#    ------------------------- --------------  7/11 [langchain-openai]
#    ------------------------- --------------  7/11 [langchain-openai]
#    ------------------------- --------------  7/11 [langchain-openai]
#    ------------------------- --------------  7/11 [langchain-openai]
#    ----------------------------- ----------  8/11 [langgraph-prebuilt]
#    ----------------------------- ----------  8/11 [langgraph-prebuilt]
#    -------------------------------- -------  9/11 [langgraph]
#    -------------------------------- -------  9/11 [langgraph]
#    -------------------------------- -------  9/11 [langgraph]
#    -------------------------------- -------  9/11 [langgraph]
#    -------------------------------- -------  9/11 [langgraph]
#    -------------------------------- -------  9/11 [langgraph]
#    -------------------------------- -------  9/11 [langgraph]
#    -------------------------------- -------  9/11 [langgraph]
#    -------------------------------- -------  9/11 [langgraph]
#    -------------------------------- -------  9/11 [langgraph]
#    -------------------------------- -------  9/11 [langgraph]
#    -------------------------------- -------  9/11 [langgraph]
#    -------------------------------- -------  9/11 [langgraph]
#    -------------------------------- -------  9/11 [langgraph]
#    ------------------------------------ --- 10/11 [langchain]
#    ------------------------------------ --- 10/11 [langchain]
#    ------------------------------------ --- 10/11 [langchain]
#    ------------------------------------ --- 10/11 [langchain]
#    ------------------------------------ --- 10/11 [langchain]
#    ------------------------------------ --- 10/11 [langchain]
#    ---------------------------------------- 11/11 [langchain]
#
# Successfully installed jiter-0.15.0 langchain-1.3.4 langchain-openai-1.2.2 langgraph-1.2.4 langgraph-checkpoint-4.1.1 langgraph-prebuilt-1.1.0 langgraph-sdk-0.4.2 openai-2.41.0 ormsgpack-1.12.2 tiktoken-0.13.0 websockets-15.0.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
from langchain.chat_models import init_chat_model

os.environ["OPENAI_API_KEY"] = "SK-ENTER UR OPENAI API KEY HERE"

model = init_chat_model("gpt-5.2")

# %%
response = model.invoke("job opportunity in 2027")
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 response = model.invoke("job opportunity in 2027")
#
# File c:\Users\sweth\Anaconda3_New\Lib\site-packages\langchain_core\language_models\chat_models.py:474, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     460 @override
#     461 def invoke(
#     462     self,
#    (...)    467     **kwargs: Any,
#     468 ) -> AIMessage:
#     469     config = ensure_config(config)
#     470     return cast(
#     471         "AIMessage",
#     472         cast(
#     473             "ChatGeneration",
# --> 474             self.generate_prompt(
#     475                 [self._convert_input(input)],
#     476                 stop=stop,
#     477                 callbacks=config.get("callbacks"),
#     478                 tags=config.get("tags"),
#     479                 metadata=config.get("metadata"),
#     480                 run_name=config.get("run_name"),
#     481                 run_id=config.pop("run_id", None),
#     482                 **kwargs,
#     483             ).generations[0][0],
#     484         ).message,
#     485     )
#
# File c:\Users\sweth\Anaconda3_New\Lib\site-packages\langchain_core\language_models\chat_models.py:1823, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1814 @override
#    1815 def generate_prompt(
#    1816     self,
#    (...)   1820     **kwargs: Any,
#    1821 ) -> LLMResult:
#    1822     prompt_messages = [p.to_messages() for p in prompts]
# -> 1823     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File c:\Users\sweth\Anaconda3_New\Lib\site-packages\langchain_core\language_models\chat_models.py:1630, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#    1627 for i, m in enumerate(input_messages):
#    1628     try:
#    1629         results.append(
# -> 1630             self._generate_with_cache(
#    1631                 m,
#    1632                 stop=stop,
#    1633                 run_manager=run_managers[i] if run_managers else None,
#    1634                 **kwargs,
#    1635             )
#    1636         )
#    1637     except BaseException as e:
#    1638         if run_managers:
#
# File c:\Users\sweth\Anaconda3_New\Lib\site-packages\langchain_core\language_models\chat_models.py:1970, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1968     result = generate_from_stream(iter(chunks))
#    1969 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1970     result = self._generate(
#    1971         messages, stop=stop, run_manager=run_manager, **kwargs
#    1972     )
#    1973 else:
#    1974     result = self._generate(messages, stop=stop, **kwargs)
#
# File c:\Users\sweth\Anaconda3_New\Lib\site-packages\langchain_openai\chat_models\base.py:1667, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#    1665     _handle_openai_bad_request(e)
#    1666 except openai.APIError as e:
# -> 1667     _handle_openai_api_error(e)
#    1668 except Exception as e:
#    1669     if raw_response is not None and hasattr(raw_response, "http_response"):
#
# File c:\Users\sweth\Anaconda3_New\Lib\site-packages\langchain_openai\chat_models\base.py:1662, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#    1655         return _construct_lc_result_from_responses_api(
#    1656             response,
#    1657             schema=original_schema_obj,
#    1658             metadata=generation_info,
#    1659             output_version=self.output_version,
#    1660         )
#    1661     else:
# -> 1662         raw_response = self.client.with_raw_response.create(**payload)
#    1663         response = raw_response.parse()
#    1664 except openai.BadRequestError as e:
#
# File c:\Users\sweth\Anaconda3_New\Lib\site-packages\openai\_legacy_response.py:367, in to_raw_response_wrapper.<locals>.wrapped(*args, **kwargs)
#     363 extra_headers[RAW_RESPONSE_HEADER] = "true"
#     365 kwargs["extra_headers"] = extra_headers
# --> 367 return cast(LegacyAPIResponse[R], func(*args, **kwargs))
#
# File c:\Users\sweth\Anaconda3_New\Lib\site-packages\openai\_utils\_utils.py:298, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     296             msg = f"Missing required argument: {quote(missing[0])}"
#     297     raise TypeError(msg)
# --> 298 return func(*args, **kwargs)
#
# File c:\Users\sweth\Anaconda3_New\Lib\site-packages\openai\resources\chat\completions\completions.py:1251, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, moderation, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, prompt_cache_retention, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1203 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    1204 def create(
#    1205     self,
#    (...)   1248     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#    1249 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#    1250     validate_response_format(response_format)
# -> 1251     return self._post(
#    1252         "/chat/completions",
#    1253         body=maybe_transform(
#    1254             {
#    1255                 "messages": messages,
#    1256                 "model": model,
#    1257                 "audio": audio,
#    1258                 "frequency_penalty": frequency_penalty,
#    1259                 "function_call": function_call,
#    1260                 "functions": functions,
#    1261                 "logit_bias": logit_bias,
#    1262                 "logprobs": logprobs,
#    1263                 "max_completion_tokens": max_completion_tokens,
#    1264                 "max_tokens": max_tokens,
#    1265                 "metadata": metadata,
#    1266                 "modalities": modalities,
#    1267                 "moderation": moderation,
#    1268                 "n": n,
#    1269                 "parallel_tool_calls": parallel_tool_calls,
#    1270                 "prediction": prediction,
#    1271                 "presence_penalty": presence_penalty,
#    1272                 "prompt_cache_key": prompt_cache_key,
#    1273                 "prompt_cache_retention": prompt_cache_retention,
#    1274                 "reasoning_effort": reasoning_effort,
#    1275                 "response_format": response_format,
#    1276                 "safety_identifier": safety_identifier,
#    1277                 "seed": seed,
#    1278                 "service_tier": service_tier,
#    1279                 "stop": stop,
#    1280                 "store": store,
#    1281                 "stream": stream,
#    1282                 "stream_options": stream_options,
#    1283                 "temperature": temperature,
#    1284                 "tool_choice": tool_choice,
#    1285                 "tools": tools,
#    1286                 "top_logprobs": top_logprobs,
#    1287                 "top_p": top_p,
#    1288                 "user": user,
#    1289                 "verbosity": verbosity,
#    1290                 "web_search_options": web_search_options,
#    1291             },
#    1292             completion_create_params.CompletionCreateParamsStreaming
#    1293             if stream
#    1294             else completion_create_params.CompletionCreateParamsNonStreaming,
#    1295         ),
#    1296         options=make_request_options(
#    1297             extra_headers=extra_headers,
#    1298             extra_query=extra_query,
#    1299             extra_body=extra_body,
#    1300             timeout=timeout,
#    1301             security={"bearer_auth": True},
#    1302         ),
#    1303         cast_to=ChatCompletion,
#    1304         stream=stream or False,
#    1305         stream_cls=Stream[ChatCompletionChunk],
#    1306     )
#
# File c:\Users\sweth\Anaconda3_New\Lib\site-packages\openai\_base_client.py:1332, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1323     warnings.warn(
#    1324         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1325         "Please pass raw bytes via the `content` parameter instead.",
#    1326         DeprecationWarning,
#    1327         stacklevel=2,
#    1328     )
#    1329 opts = FinalRequestOptions.construct(
#    1330     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1331 )
# -> 1332 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File c:\Users\sweth\Anaconda3_New\Lib\site-packages\openai\_base_client.py:1105, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1102             err.response.read()
#    1104         log.debug("Re-raising status error")
# -> 1105         raise self._make_status_error_from_response(err.response) from None
#    1107     break
#    1109 assert response is not None, "could not resolve response (should never happen)"
#
# RateLimitError: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}

# %%
print(response)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 print(response)
#
# NameError: name 'response' is not defined

# %%
print(response.text)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 print(response.text)
#
# NameError: name 'response' is not defined
