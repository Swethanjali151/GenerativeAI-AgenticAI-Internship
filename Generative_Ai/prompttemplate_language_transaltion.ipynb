# %%
import os
from langchain.chat_models import init_chat_model

os.environ["GOOGLE_API_KEY"] = "ENTER UR GEMINI API KEY HERE"

model = init_chat_model("google_genai:gemini-2.5-flash-lite")

# %%
response = model.invoke("about software jobs in 2026 to 2030?")

# %%
print(response.text)
# Out:
# The job market for software professionals between 2026 and 2030 is projected to remain strong and dynamic, driven by several key trends. While predicting the future with absolute certainty is impossible, here's a comprehensive outlook based on current trajectories and expert analysis:
#
# **Overall Outlook: Continued Growth and High Demand**
#
# *   **Sustained Demand:** The need for skilled software developers, engineers, and related professionals will continue to outpace supply. Digital transformation across industries is not slowing down; in fact, it's accelerating.
# *   **Adaptability is Key:** The landscape will evolve. Staying current with new technologies and adapting to changing needs will be crucial for long-term career success.
# *   **Global Opportunities:** The remote work trend is likely to persist, opening up global job opportunities for software professionals.
#
# **Key Trends Shaping the Software Job Market (2026-2030):**
#
# 1.  **Artificial Intelligence (AI) and Machine Learning (ML) Dominance:**
#     *   **High Demand Roles:** AI/ML Engineers, Data Scientists, Machine Learning Operations (MLOps) Engineers, AI Ethicists, Prompt Engineers.
#     *   **Impact:** AI will be integrated into almost every aspect of software development, from code generation and testing to personalized user experiences and complex data analysis. Companies will need professionals to build, deploy, and maintain these AI systems.
#
# 2.  **Cloud Computing Evolution:**
#     *   **High Demand Roles:** Cloud Architects, Cloud Engineers (AWS, Azure, GCP), DevOps Engineers, Site Reliability Engineers (SREs), Cloud Security Specialists.
#     *   **Impact:** Cloud adoption will continue its upward trajectory. Professionals skilled in cloud infrastructure, migration, optimization, and security will be essential. Serverless computing and edge computing will also gain more traction.
#
# 3.  **Cybersecurity as a Paramount Concern:**
#     *   **High Demand Roles:** Cybersecurity Engineers, Ethical Hackers, Security Analysts, DevSecOps Engineers, Blockchain Security Specialists.
#     *   **Impact:** As digital footprints expand and cyber threats become more sophisticated, the demand for cybersecurity professionals will skyrocket. Integrating security into every stage of the software development lifecycle (DevSecOps) will be the norm.
#
# 4.  **Data Engineering and Analytics:**
#     *   **High Demand Roles:** Data Engineers, Data Analysts, Business Intelligence Developers, Big Data Architects.
#     *   **Impact:** The sheer volume of data generated will continue to grow. Companies will need experts to manage, process, and derive actionable insights from this data to drive business decisions.
#
# 5.  **Full-Stack Development Remains Strong, but Specialization Increases:**
#     *   **High Demand Roles:** Full-Stack Developers (with expertise in modern frameworks), Front-End Developers, Back-End Developers.
#     *   **Impact:** While generalists will still be valuable, there will be a growing need for specialists in specific areas like front-end frameworks (React, Vue, Angular), back-end languages and frameworks (Node.js, Python/Django/Flask, Java/Spring), and database technologies.
#
# 6.  **Emerging Technologies:**
#     *   **Web3 and Blockchain:** While the hype may have cooled, the underlying technologies are still developing. Roles in decentralized applications (dApps), smart contract development, and blockchain security will persist.
#     *   **Metaverse and Extended Reality (XR):** As these technologies mature, there will be a demand for developers skilled in creating immersive experiences, 3D modeling, and VR/AR development.
#     *   **Quantum Computing:** While still in its nascent stages for widespread commercial application, early adopters and researchers will require quantum computing specialists.
#
# 7.  **Low-Code/No-Code Platform Integration:**
#     *   **Impact:** These platforms will empower citizen developers and accelerate application development for simpler tasks. However, they will also create a need for professionals who can build, integrate, and manage these platforms, as well as develop custom solutions for more complex requirements.
#
# 8.  **Focus on Developer Experience (DevEx) and Efficiency:**
#     *   **High Demand Roles:** Developer Advocates, Tools Engineers, Platform Engineers.
#     *   **Impact:** Companies will invest more in tools and processes that improve developer productivity, streamline workflows, and enhance job satisfaction.
#
# **Skills in Demand:**
#
# *   **Programming Languages:** Python, JavaScript (and its frameworks like React, Node.js), Java, Go, C#, Rust.
# *   **Cloud Platforms:** AWS, Azure, Google Cloud Platform.
# *   **AI/ML Frameworks:** TensorFlow, PyTorch, Scikit-learn.
# *   **Data Technologies:** SQL, NoSQL databases, Apache Spark, Kafka.
# *   **DevOps Tools:** Docker, Kubernetes, CI/CD pipelines (Jenkins, GitLab CI, GitHub Actions).
# *   **Cybersecurity Principles:** Network security, application security, cryptography.
# *   **Soft Skills:** Problem-solving, critical thinking, communication, collaboration, adaptability, continuous learning.
#
# **Potential Challenges and Considerations:**
#
# *   **Rapid Obsolescence of Skills:** Technologies evolve quickly, requiring constant learning and upskilling.
# *   **Intensified Competition:** While demand is high, the influx of new talent and the global nature of the job market can lead to competition for top roles.
# *   **Ethical Considerations:** AI and data privacy raise ethical concerns that will require professionals with a strong understanding of responsible technology development.
# *   **Economic Fluctuations:** While the tech sector is generally resilient, broader economic downturns can still impact hiring and investment.
#
# **Advice for Aspiring and Current Software Professionals:**
#
# *   **Embrace Lifelong Learning:** Continuously acquire new skills and stay updated with emerging technologies.
# *   **Specialize Strategically:** While a broad understanding is good, developing deep expertise in a high-demand niche can be very beneficial.
# *   **Build a Strong Portfolio:** Showcase your projects and skills through GitHub, personal websites, or contributions to open-source projects.
# *   **Network Actively:** Connect with other professionals, attend conferences, and participate in online communities.
# *   **Develop Strong Soft Skills:** Communication, teamwork, and problem-solving are as crucial as technical abilities.
# *   **Consider Certifications:** Relevant certifications in cloud, cybersecurity, or specific technologies can boost your credibility.
# *   **Stay Informed About Industry Trends:** Read tech news, follow influential figures, and research market reports.
#
# In summary, the software job market from 2026 to 2030 is expected to be a landscape of significant opportunity for those who are adaptable, continuously learning, and possess in-demand skills, particularly in areas like AI, cloud computing, and cybersecurity.

# %% [markdown]
# # Language Translation

# %%
from langchain_core.messages import HumanMessage, SystemMessage

messages = [
    SystemMessage("Translate the following from English into odia language"),
    HumanMessage("how are you teams working on langchain with google gemini model?"),
]
model.invoke(messages)
# Out:
# AIMessage(content='Here are a few ways to translate "How are your teams working on Langchain with Google Gemini model?" into Odia, with slight nuances:\n\n**Most direct and common:**\n\n*   **ଆପଣଙ୍କ ଦଳ ଗୁଗଲ୍ ଜେମିନି ମଡେଲ୍ ସହିତ ଲାଙ୍ଗଚେନରେ କିପରି କାମ କରୁଛନ୍ତି?**\n    (Apanaṅka daḷa Google Gemini moḍel sahitē Lāṅgcēnare kipari kāma karuchanti?)\n\n**Slightly more formal/detailed:**\n\n*   **ଆପଣଙ୍କ ଟିମ୍ ଗୁଗଲ୍ ଜେମିନି ମଡେଲ୍ ବ୍ୟବହାର କରି ଲାଙ୍ଗଚେନ ଉପରେ କିପରି କାର୍ଯ୍ୟ କରୁଛନ୍ତି?**\n    (Apanaṅka ṭim Google Gemini moḍel byabahāra kari Lāṅgcēna uparē kipari kārya karuchanti?)\n    *   "କାର୍ଯ୍ୟ କରୁଛନ୍ତି" (kārya karuchanti) is a more formal way of saying "working."\n\n**Focusing on the process:**\n\n*   **ଗୁଗଲ୍ ଜେମିନି ମଡେଲ୍ ସହିତ ଲାଙ୍ଗଚେନ ଉପରେ ଆପଣଙ୍କ ଦଳର କାର୍ଯ୍ୟ ପ୍ରଣାଳୀ କଣ?**\n    (Google Gemini moḍel sahitē Lāṅgcēna uparē apanaṅka daḷara kārya praṇāḷī kaṇa?)\n    *   This asks about the "working process" or "methodology."\n\n**Key vocabulary:**\n\n*   **ଆପଣଙ୍କ (Apanaṅka):** Your (formal)\n*   **ଦଳ (Daḷa) / ଟିମ୍ (Ṭim):** Team\n*   **ଗୁଗଲ୍ (Google):** Google\n*   **ଜେମିନି (Gemini):** Gemini\n*   **ମଡେଲ୍ (Moḍel):** Model\n*   **ସହିତ (Sahitē):** With\n*   **ଲାଙ୍ଗଚେନ (Lāṅgcēna):** Langchain\n*   **କିପରି (Kipari):** How\n*   **କାମ କରୁଛନ୍ତି (Kāma karuchanti):** Are working\n*   **ବ୍ୟବହାର କରି (Byabahāra kari):** Using\n*   **ଉପରେ (Uparē):** On\n*   **କାର୍ଯ୍ୟ କରୁଛନ୍ତି (Kārya karuchanti):** Are working (more formal)\n*   **କାର୍ଯ୍ୟ ପ୍ରଣାଳୀ (Kārya praṇāḷī):** Working process/methodology\n\nChoose the option that best fits the context and level of formality you intend. The first option is generally the most straightforward and widely understood.', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019e96bc-2fd4-7cf0-9055-a3c435f2e2a7-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 23, 'output_tokens': 662, 'total_tokens': 685, 'input_token_details': {'cache_read': 0}})

# %%
response1 = model.invoke(messages)

# %%
print(response1.text)
# Out:
# Google Gemini ରେ Langchain ଟିମ୍ କିପରି କାର୍ଯ୍ୟ କରୁଛି?

# %%
from langchain_core.messages import HumanMessage, SystemMessage

messages = [
    SystemMessage("Translate the following from hindi into english language"),
    HumanMessage("बहुत अच्छा टीम वर्क कर रहे हो आप लोग"), 
]

model.invoke(messages)
# Out:
# AIMessage(content='You guys are doing great teamwork.', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019e96bd-359a-74d0-8c00-068c98b44355-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 18, 'output_tokens': 7, 'total_tokens': 25, 'input_token_details': {'cache_read': 0}})

# %%
response2 = model.invoke(messages)

# %%
print(response2.text)
# Out:
# Here are a few ways to translate "बहुत अच्छा टीम वर्क कर रहे हो आप लोग" into English, with slight variations in nuance:
#
# **Most common and direct:**
#
# *   **You all are doing great teamwork.**
# *   **You guys are doing great teamwork.** (More informal)
# *   **You are doing a great job of teamwork.**
#
# **Slightly more emphatic:**
#
# *   **Excellent teamwork you all are doing!**
# *   **You're demonstrating excellent teamwork.**
#
# **Focusing on the effort:**
#
# *   **You're all working together very well.**
# *   **Your teamwork is really good.**
#
# The best translation will depend on the specific context and the level of formality you want to convey.

# %%
model.invoke("Hello")
model.invoke([{"role": "user", "content": "Hello"}])
model.invoke([HumanMessage("Hello")])
# Out:
# AIMessage(content='Hello there! How can I help you today?', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019e96be-a556-7f03-a9bf-f70bc479728c-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 2, 'output_tokens': 10, 'total_tokens': 12, 'input_token_details': {'cache_read': 0}})

# %% [markdown]
# # Prompt Template

# %%
from langchain_core.prompts import ChatPromptTemplate

system_template = "Translate the following from English into {language}"

prompt_template = ChatPromptTemplate.from_messages(
    [("system", system_template), ("user", "{text}")]
)

# %%
prompt = prompt_template.invoke({"language": "odia", "text": "how are you"})
prompt
# Out:
# ChatPromptValue(messages=[SystemMessage(content='Translate the following from English into odia', additional_kwargs={}, response_metadata={}), HumanMessage(content='how are you', additional_kwargs={}, response_metadata={})])

# %%
prompt.to_messages()
# Out:
# [SystemMessage(content='Translate the following from English into odia', additional_kwargs={}, response_metadata={}),
#  HumanMessage(content='how are you', additional_kwargs={}, response_metadata={})]

# %%
response3 = model.invoke(prompt)
print(response3.content)
# Out:
# ମୁଁ ଭଲ ଅଛି, ଧନ୍ୟବାଦ! ତୁମେ କେମିତି ଅଛ?
