# %%
pip install -qU "langchain[google-genai]"
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import os

# Set the API key (Note: avoid hardcoding sensitive keys in production)
os.environ["GOOGLE_API_KEY"] = "AQ. ENTER UR GEMINI API KEY HERE"

# Import the correct class for using Gemini models via LangChain
from langchain_google_genai import ChatGoogleGenerativeAI

# Initialize the model (use "gemini-1.5-flash" or "gemini-1.5-pro" – not "2.0-flash" as it doesn't exist)
model = ChatGoogleGenerativeAI(model="gemini-2.5-flash")

# Test the model
response = model.invoke("What's the capital of France?")
print(response.content)
# Out:
# The capital of France is **Paris**.

# %%
model.invoke("About Generative AI and Agentic AI")
# Out:
# AIMessage(content='Generative AI and Agentic AI represent two distinct, yet often complementary, paradigms within the broader field of artificial intelligence. Understanding their core differences and how they can interact is crucial for grasping the current and future landscape of AI.\n\n---\n\n## Generative AI\n\n**What it is:**\nGenerative AI refers to a class of AI models capable of producing novel and realistic content, such as text, images, audio, video, or code, that resembles the data they were trained on. Instead of just classifying or predicting, these models *create*.\n\n**How it Works:**\nGenerative models learn patterns, structures, and relationships within vast datasets during their training phase. Once trained, they can use this learned understanding to generate entirely new samples that share the characteristics of the training data, but are not direct copies.\n\n**Key Characteristics:**\n1.  **Creation:** Generates new content from a prompt or input.\n2.  **Pattern Learning:** Excels at understanding and replicating complex data distributions.\n3.  **Content Variety:** Can produce diverse outputs (text, images, audio, etc.) depending on the model architecture.\n4.  **Often Probabilistic:** The output isn\'t deterministic; multiple valid generations can arise from the same prompt.\n\n**Examples:**\n*   **Large Language Models (LLMs):** ChatGPT, GPT-4, Bard, Llama 2 (generating text, code, summaries, translations).\n*   **Image Generators:** DALL-E, Midjourney, Stable Diffusion (creating images from text descriptions).\n*   **Audio Generators:** Models that create music, speech, or sound effects.\n*   **Video Generators:** Models that create short video clips from text or images.\n*   **Code Generators:** GitHub Copilot, Amazon CodeWhisperer (generating code snippets or entire functions).\n\n**Applications:**\nContent creation, design, art, software development, data augmentation, personalized marketing, education.\n\n**Limitations:**\nCan "hallucinate" or produce factually incorrect information, may perpetuate biases present in training data, lacks true understanding or common sense, can be computationally expensive.\n\n---\n\n## Agentic AI (or AI Agents)\n\n**What it is:**\nAgentic AI refers to intelligent systems designed to act autonomously in an environment to achieve a specific goal or set of goals. Unlike generative models that primarily focus on producing content, AI agents are built to *plan, execute, and adapt* a sequence of actions.\n\n**How it Works:**\nAn AI agent typically operates through a loop that involves:\n1.  **Perception:** Gathering information from its environment (e.g., reading web pages, querying databases, interpreting user input).\n2.  **Planning:** Breaking down a complex goal into smaller, manageable steps. This often involves reasoning and decision-making.\n3.  **Action:** Executing the planned steps, which might involve using tools (APIs, web browsers, other AI models), interacting with software, or controlling physical robots.\n4.  **Memory/Reflection:** Remembering past interactions and outcomes, and reflecting on progress to refine future actions or plans.\n5.  **Feedback Loop:** Continuously monitoring the environment and its own actions, and adjusting its strategy based on feedback.\n\n**Key Characteristics:**\n1.  **Goal-Oriented:** Designed to accomplish specific objectives.\n2.  **Autonomy:** Can make decisions and take actions independently without constant human intervention.\n3.  **Tool Use:** Often leverages external tools, APIs, and other AI models (including generative AI) to perform tasks.\n4.  **Context & Memory:** Maintains a state and remembers past interactions to inform future actions.\n5.  **Iterative Process:** Operates in a loop of perception, planning, and action, often with self-correction.\n6.  **Environmental Interaction:** Actively engages with its environment, rather than just producing static output.\n\n**Examples:**\n*   **Autonomous Task Execution:* ...

# %%
import streamlit as st
st.write("welcome")
# Out:
# 2026-06-07 12:59:36.502 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-07 12:59:36.517 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-07 12:59:36.526 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
